# %%
! pip install tweepy
! pip install textblob

# %% [markdown]
# # Collect Tweets

# %%
import tweepy
import twitter_credentials
import pandas as pd
import numpy as np
import re
from textblob import TextBlob
from datetime import datetime, timedelta

# %%
class TweetCollector():
	"""
	Class for collecting and processing tweets.
	"""

	def clean_tweet(self, tweet):
		return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

	def collect_tweets(self, hashtag, max_tweets):
		tweets = []
		for tweet in tweepy.Cursor(api.search, q=hashtag, lang='en').items(MAX_TWEETS):
			tweets.append(tweet)

		return tweets

	def get_user_timeline_tweets(self, num_tweets):
		tweets = []
		for tweet in Cursor(self.twitter_client.user_timeline, id=self.twitter_user).items(num_tweets):
			tweets.append(tweet)
		return tweets

	def tweets_to_data_frame(self, tweets, to_csv=False):
		df = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['tweets'])

		df['id'] = np.array([tweet.id for tweet in tweets])
		df['len'] = np.array([len(tweet.text) for tweet in tweets])
		df['date'] = np.array([tweet.created_at for tweet in tweets])
		df['source'] = np.array([tweet.source for tweet in tweets])
		df['likes'] = np.array([tweet.favorite_count for tweet in tweets])
		df['retweets'] = np.array([tweet.retweet_count for tweet in tweets])
		
		if to_csv:
			df.to_csv('tweets_df.csv')

		return df
			

	def analyze_sentiment(self, tweet):
		analysis = TextBlob(tweet)
		
		'''
		if analysis.sentiment.polarity > 0:
			return 1
		elif analysis.sentiment.polarity == 0:
			return 0
		else:
			return -1
		'''

		return analysis.sentiment.polarity

# %%
MAX_TWEETS = 10000
since = '2020-01-01'
until = datetime.today().strftime('%Y-%m-%d')

# Authentication
auth = tweepy.OAuthHandler(twitter_credentials.CONSUMER_KEY, twitter_credentials.CONSUMER_SECRET)
api = tweepy.API(auth)

# Create object
tweet_collector = TweetCollector()

# Collect tweets into dataframe
tweets = tweet_collector.collect_tweets(hashtag="#AAPL since:{} until:{}".format(since, until), max_tweets=MAX_TWEETS)
tweets_df = tweet_collector.tweets_to_data_frame(tweets)

# Clean tweets
tweets_df['tweets'] = pd.DataFrame([tweet_collector.clean_tweet(tweet) for tweet in tweets_df['tweets']])
tweets_df = tweets_df.drop_duplicates(subset=['tweets'])

# Analyze sentiment with TextBlob
tweets_df['sentiment'] = np.array([tweet_collector.analyze_sentiment(tweet) for tweet in tweets_df['tweets']])

#[print(tweet, sent) for tweet, sent in zip(tweets_df['tweets'][:30], tweets_df['sentiment'][:30])]

# %%
print('daily sentiment score for {} to {}: '.format(since, until),  tweets_df['sentiment'].sum())
# Out:
# daily sentiment score for 2020-01-01 to 2020-08-10:  100.3658335969586

# %% [markdown]
# # Remove Spam

# %% [markdown]
# Some tweets may be spam, so we try to remove the sources that generally don't contain quality information about sentiment.

# %%
import matplotlib.pyplot as plt

# %%
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 740 entries, 0 to 870
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweets     740 non-null    object
#  1   id         740 non-null    int64
#  2   len        740 non-null    int64
#  3   date       740 non-null    datetime64[ns]
#  4   source     740 non-null    object
#  5   likes      740 non-null    int64
#  6   retweets   740 non-null    int64
#  7   sentiment  740 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(2)
# memory usage: 52.0+ KB

# %%
tweets_df['source'].unique()
# Out:
# array(['Twitter for Android', 'Twitter for iPhone', 'Twitter Web App',
#        'dlvr.it', 'MagicPot', 'TweetDeck', 'UTDStockNews',
#        'Twitter for iPad', 'Robinheed Upgraded', 'Bot Libre!', 'SpinyApp',
#        'Zapier.com', 'TradingView', 'StockTwits Web', 'IFTTT',
#        'TQ Alerts', 'Hootsuite Inc.', 'Google',
#        'Crypto Overvalued/Undervalued', '', 'Gambiste', 'Instagram',
#        'YOUNG APP', 'WordPress.com', 'HFT DeskTop v2.x', 'Hyderabad Bot',
#        'Twitter for Mac', 'Apple Retweet Bot', 'TalkMarketsApp',
#        'Donald Ndoro 2', 'Buffer', 'MeetEdgar', 'paulcrypto'],
#       dtype=object)

# %% [markdown]
# ### Cumulative Sentiment

# %%
cum_sentiment = []
for source in tweets_df['source'].unique():
    cum_sentiment.append(tweets_df[tweets_df['source'] == source]['sentiment'].sum() / tweets_df['sentiment'].sum())

#tweets_df['cum_sentiment'] = np.cumsum(tweets_df['sentiment'])
#tweets_df['cum_sentiment'].sort_values('c', ascending=False)[['a','b']].plot.bar(stacked=True)

cols = ['#99003d' if x < 0 else '#009900' for x in cum_sentiment]

plt.bar(range(len(cum_sentiment)), cum_sentiment, color=cols)
plt.xticks(range(len(cum_sentiment)), tweets_df['source'].unique(), rotation='vertical')
plt.hlines(np.mean(cum_sentiment), xmin=-0.5, xmax=len(cum_sentiment)-0.5, linestyles='--', linewidth=0.5, label='mean')
plt.ylabel('cumulative sentiment [%]')
plt.show()

# %% [markdown]
# We see that some sources have a higher impact on daily sentiment than others.

# %% [markdown]
# ### Retweets

# %%
cum_retweets = []
for source in tweets_df['source'].unique():
    cum_retweets.append(tweets_df[tweets_df['source'] == source]['retweets'].sum() / tweets_df['retweets'].sum())

plt.bar(range(len(cum_retweets)), cum_retweets)
plt.xticks(range(len(cum_retweets)), tweets_df['source'].unique(), rotation='vertical')
plt.hlines(np.mean(cum_retweets), xmin=-0.5, xmax=len(cum_retweets)-0.5, linestyles='--', linewidth=0.5, label='mean')
plt.ylabel('cumulative retweets [%]')
plt.show()

# %% [markdown]
# We see that some sources are never or rarely retweeted, possibly indicating they have useless content.

# %% [markdown]
# ### Cum. Sentiment and Retweets

# %%
plt.bar(tweets_df['source'].unique(), cum_sentiment, color='teal', label='sentiment')
plt.bar(tweets_df['source'].unique(), cum_retweets, bottom=cum_sentiment, color='c', label='retweets')
plt.hlines(y=np.mean(cum_sentiment+cum_retweets), xmin=-0.5, xmax=len(cum_retweets)-0.5, linestyles='--', linewidth=0.5, label='mean')
plt.ylabel('cum_sentiment+cum_retweets')
plt.xticks(range(len(cum_retweets)), tweets_df['source'].unique(), rotation='vertical')
plt.legend()
plt.show()

# %% [markdown]
# We exclude sources with Cum. Sentiment and Retweet under a given threshhold (mean sentiment or retweets), as a source could have a lot of weight on sentiment but no retweets. We could also choose a certain quantile as threshhold.

# %%
sent_to_drop = tweets_df['source'].unique()[cum_sentiment < np.mean(cum_sentiment)]
ret_to_drop = tweets_df['source'].unique()[cum_retweets < np.mean(cum_retweets)]
to_drop = list(set(sent_to_drop) | set(ret_to_drop))

# %%
tweets_df = tweets_df[~tweets_df['source'].isin(to_drop)]

# %%
tweets_df['source'].unique()
# Out:
# array(['Twitter for Android', 'Twitter for iPhone', 'Twitter Web App'],
#       dtype=object)

# %%
tweets_df.shape
# Out:
# (358, 8)

# %%
# Save csv
tweets_df.to_csv('tweets_df.csv', header=True, index=None)

# %% [markdown]
# The textblob module for sentiment analysis is not great. Will implement BERT.

# %% [markdown]
# # Compute Sentiment Score for Date Range with TextBlob

# %%
gb = tweets_df.groupby(tweets_df.date.dt.date)

# %%
gb.get_group('2020-08-07')
# Out:
#                                                 tweets                   id  \
# 110  Someone on aznidentity using the Romance of th...  1291877624436781057
# 112                                     AAPL chart via  1291873103740653576
# 113  what are your picks to click if the heals act ...  1291857107608834065
# 115  Welcome to the Pack Wolf Trading Co is here to...  1291850976761131010
# 118  SPY CNN Fear amp Greed Index Now Greed 71 ES F...  1291848612239089667
# 119  SPY barchart Fri Unusual Options Activity More...  1291847726360076290
# 120  SPY barchart Fri New 52 week Lows 7 ES F NQ F ...  1291846983351775233
# 122  SPY barchart Fri New 52 weeks highs 175 stocks...  1291846734637924352
# 124  Apple AAPL STOP draining my iPhone11 battery t...  1291846289781596166
# 125  SPY barchart Fri Stock Market Momentum ES F NQ...  1291846194893926400
# 127  SPY CNBC Fri Market Movers S amp P UPS FedEx b...  1291844852834078722
# 128  RT 3s SPY Finviz Fri Heat Map Tech stocks down...  1291844850929762312
# 129  SPY Finviz Fri Heat Map Tech stocks down But F...  1291844552643481607
# 130  SPY Finviz Fri Markets Dow Up S amp P Flat Gre...  1291844304613384199
# 132  aapl aapl is that you yoda Are you speaking ap...  1291831727594373123
# 135  ES F What AAPL down today What s the world com...  1291823038632275968
# 136  SPY Nasdaq not having a good day ES F NQ F SPY...  1291822523768877056
# 137  Apple s closing estimate 445 450 Disclaimer No...  1291822093655584770
# 139  RT ct aapl amzn msft down over 2 spy down 0 38...  1291811023733678080
# 140  aapl amzn msft down over 2 spy down 0 38 The w...  1291810595562553345
# 142  Charts are the Best indicator to make money Tr...  1291806783217041414
# 143                            RT AAPL No words needed  1291803490214453249
# 146  The On Balance Volume Indicator for people who...  1291792389582053377
# 149  Diversification is protection against ignoranc...  1291781824121798657
# 150  anyone else buy more aapl before the stock spl...  1291780555172753408
# 151  AAPL I am still long Not big size though For n...  1291777060445270020
# 152  talk about rotation aka extracting out from ma...  1291769357589254145
# 153  AAPL I really know what the 4 1 stock split is...  1291769075039965186
# 156  RT is not going to do anything that would crea...  1291764703115522050
# 157  Apple Inc AAPL shares are down 0 76 in the cur...  1291764134904832000
# 158  is not going to do anything that would create ...  1291760328720580609
# 163                       Investors still needs AAPL s  1291751291098669057
# 166  Want to see what Smart Money is trading Join Q...  1291748424157663234
# 169  My Video has 3 stocks setting up perfectly to ...  1291742788166524928
# 171  Your free stock is waiting for you Join Robinh...  1291735783976534018
# 172  RT Careful what you ask for If Trust Wallet ca...  1291731636682395651
# 173  Careful what you ask for If Trust Wallet can w...  1291728859474333697
# 174           RH acting up today aapl aapl apple stock  1291727579100123138
# 175  So AAPL went up 0 82 cents according to RH and...  1291726058216140800
# 177  Should AAPL launch its own cryptoshit and the ...  1291717348857122816
# 182  AAPL has more cash than turkish residents s fx...  1291711137755664384
# 187  If governments put the financial system under ...  1291672302833278978
# 190  My last video has 2 stocks setting up perfectl...  1291661297835216896
# 193                               AAPL No words needed  1291643412404490241
# 195  Also Apple Aapl worth almost half a trillion m...  1291630244286341121
# 196  Join us with 50 off Platinum Plan and learn to...  1291625392940490753
# 199            Soon to be First 2T company AAPL NASDAQ  1291609687587033088
# 200  Market Stock Market Action Buy and Hold Put op...  1291601809740640256
# 201  Ever time some analyst warns is overpriced and...  1291600135474962432
# 203  Today we had DIS calls from 19 all the way to ...  1291591721751584769
# 207      Apples stock split Does it really matter aapl  1291587413517774850
# 211  Today s Musings Wild Earnings amp Current Posi...  1291568247981199363
# 215  AAPL AAPL Trendline resistance is around 495 b...  1291565814374526978
# 216  AAPL share price adds 1 will value the company...  1291565096246935553
# 217  Made a tad bit of guap today And I do mean tad...  1291562953653747712
# 219  SPY Back to ATHs almost Recession Corona Pande...  1291561279090565121
# 221  ES F There is a big difference b w scalping an...  1291545955037110272
# 222  SPY Q Did u make today honest response I know ...  1291540148598067200
# 223  AAPL Just short of 52 billion to hit 2 Trillio...  1291528251609948160
# 224  I ve been doing ok using call spreads long aap...  1291524960108916736
#
#      len                date               source  likes  retweets  sentiment
# 110  137 2020-08-07 23:23:22   Twitter for iPhone     13         0   0.000000
# 112   74 2020-08-07 23:05:24      Twitter Web App      0         0   0.000000
# 113   99 2020-08-07 22:01:50   Twitter for iPhone      0         0   0.000000
# 115  140 2020-08-07 21:37:28   Twitter for iPhone      1         1   0.433333
# 118  140 2020-08-07 21:28:05      Twitter Web App      5         0   0.000000
# 119  138 2020-08-07 21:24:33      Twitter Web App      4         0   0.350000
# 120  136 2020-08-07 21:21:36      Twitter Web App      3         0   0.136364
# 122  132 2020-08-07 21:20:37      Twitter Web App      2         0   0.136364
# 124  110 2020-08-07 21:18:51   Twitter for iPhone      0         1   0.000000
# 125  137 2020-08-07 21:18:28      Twitter Web App      5         1   0.000000
# 127  144 2020-08-07 21:13:08      Twitter Web App      4         0   0.000000
# 128  140 2020-08-07 21:13:08      Twitter Web App      0         1  -0.155556
# 129  136 2020-08-07 21:11:57      Twitter Web App      4         1  -0.155556
# 130  144 2020-08-07 21:10:58      Twitter Web App      4         0  -0.126852
# 132   82 2020-08-07 20:20:59  Twitter for Android      0         0   0.000000
# 135  138 2020-08-07 19:46:27      Twitter Web App      1         0  -0.155556
# 136  138 2020-08-07 19:44:25      Twitter Web App      2         0   0.700000
# 137  136 2020-08-07 19:42:42  Twitter for Android      0         0   0.000000
# 139  109 2020-08-07 18:58:43   Twitter for iPhone      0         2  -0.155556
# 140   97 2020-08-07 18:57:01   Twitter for iPhone     11         2  -0.155556
# 142  140 2020-08-07 18:41:52      Twitter Web App      0         0   1.000000
# 143   65 2020-08-07 18:28:47      Twitter Web App      0         2   0.000000
# 146  140 2020-08-07 17:44:40      Twitter Web App      3         0   0.000000
# 149  140 2020-08-07 17:02:41   Twitter for iPhone      0         0  -0.187500
# 150   74 2020-08-07 16:57:39      Twitter Web App      1         0   0.500000
# 151  139 2020-08-07 16:43:45      Twitter Web App      5         0  -0.025000
# 152  140 2020-08-07 16:13:09      Twitter Web App      0         0   0.000000
# 153  139 2020-08-07 16:12:02      Twitter Web App      0         0   0.100000
# 156  140 2020-08-07 15:54:39      Twitter Web App      0         1   0.000000
# 157  126 2020-08-07 15:52:24      Twitter Web App      1         1  -0.077778
# 158  139 2020-08-07 15:37:16      Twitter Web App      3         1   0.000000
# 163   30 2020-08-07 15:01:22      Twitter Web App      0         0   0.000000
# 166  140 2020-08-07 14:49:58  Twitter for Android      0         0   0.071429
# 169  140 2020-08-07 14:27:34      Twitter Web App      0         0   0.500000
# 171  140 2020-08-07 13:59:44  Twitter for Android      1         0   0.400000
# 172  140 2020-08-07 13:43:16      Twitter Web App      0         1  -0.100000
# 173  139 2020-08-07 13:32:13      Twitter Web App      4         1  -0.100000
# 174   69 2020-08-07 13:27:08  Twitter for Android      0         0   0.000000
# 175  128 2020-08-07 13:21:06  Twitter for Android      0         0  -0.155556
# 177  139 2020-08-07 12:46:29  Twitter for Android      0         0   0.300000
# 182   80 2020-08-07 12:21:48   Twitter for iPhone      1         0   0.500000
# 187  140 2020-08-07 09:47:29   Twitter for iPhone      0         0   0.000000
# 190  140 2020-08-07 09:03:45  Twitter for Android      1         1   0.333333
# 193   47 2020-08-07 07:52:41      Twitter Web App      4         2   0.000000
# 195   82 2020-08-07 07:00:22   Twitter for iPhone      0         0  -0.091667
# 196  144 2020-08-07 06:41:05      Twitter Web App      0         0   0.000000
# 199   68 2020-08-07 05:38:41  Twitter for Android      1         0   0.250000
# 200  138 2020-08-07 05:07:22   Twitter for iPhone      0         0   0.100000
# 201   89 2020-08-07 05:00:43      Twitter Web App      1         0   0.000000
# 203  140 2020-08-07 04:27:17   Twitter for iPhone      0         0   0.187500
# 207   72 2020-08-07 04:10:10   Twitter for iPhone      0         0   0.200000
# 211  144 2020-08-07 02:54:01      Twitter Web App      1         1   0.016667
# 215  140 2020-08-07 02:44:20      Twitter Web App     28         9   0.000000
# 216   87 2020-08-07 02:41:29   Twitter for iPhone      0         0   0.000000
# 217   86 2020-08-07 02:32:58   Twitter for iPhone      0         0  -0.312500
# 219  139 2020-08-07 02:26:19      Twitter Web App      9         0  -0.250000
# 221  139 2020-08-07 01:25:26      Twitter Web App     27         0   0.100000
# 222  148 2020-08-07 01:02:21      Twitter Web App      0         0   0.600000
# 223   85 2020-08-07 00:15:05      Twitter Web App      9         0   0.000000
# 224   74 2020-08-07 00:02:00   Twitter for iPhone      0         0   0.225000

# %%
daily_sentiment = {}
dates = pd.to_datetime(tweets_df.date.dt.strftime('%Y-%m-%d')).unique()
daily_sentiment['dates'] = dates
daily_sentiment['sentiment'] = [gb.get_group(date).sentiment.sum() for date in dates]

# %%
daily_sentiment = pd.DataFrame(daily_sentiment)
daily_sentiment
# Out:
#        dates  sentiment
# 0 2020-08-09   1.104432
# 1 2020-08-08   1.187872
# 2 2020-08-07   4.935360
# 3 2020-08-06   3.819744
# 4 2020-08-05   4.657285
# 5 2020-08-04   7.028066
# 6 2020-08-03   7.653068
# 7 2020-08-02   2.008207
# 8 2020-08-01   1.637229

# %%
! pip install yfinance

# %%
import yfinance as yf

# %%
dates = pd.to_datetime(tweets_df.date.dt.strftime('%Y-%m-%d').unique())
dates
# Out:
# DatetimeIndex(['2020-08-09', '2020-08-08', '2020-08-07', '2020-08-06',
#                '2020-08-05', '2020-08-04', '2020-08-03', '2020-08-02',
#                '2020-08-01'],
#               dtype='datetime64[ns]', freq=None)

# %%
aapl = yf.download('AAPL',dates[-1].strftime('%Y-%m-%d'),dates[0].strftime('%Y-%m-%d'))
aapl.shape
# Out:
# [*********************100%***********************]  1 of 1 completed
# (5, 6)

# %% [markdown]
# # PLOT

# %%
drop_idx = list(set(daily_sentiment.dates[::-1]) - set(aapl.index))
drop_idx
# Out:
# [Timestamp('2020-08-08 00:00:00'),
#  Timestamp('2020-08-09 00:00:00'),
#  Timestamp('2020-08-01 00:00:00'),
#  Timestamp('2020-08-02 00:00:00')]

# %%
daily_sentiment = daily_sentiment[~daily_sentiment.dates.isin(drop_idx)]
daily_sentiment
# Out:
#        dates  sentiment
# 2 2020-08-07   4.935360
# 3 2020-08-06   3.819744
# 4 2020-08-05   4.657285
# 5 2020-08-04   7.028066
# 6 2020-08-03   7.653068

# %%
fig, ax1 = plt.subplots()

ax1.plot(range(aapl.shape[0]), aapl['Close'], '-o')
ax1.set_ylabel('AAPL stock price')
ax2 = ax1.twinx()
ax2.bar(range(aapl.shape[0]), daily_sentiment.sentiment, alpha=0.5)
ax2.set_ylabel('Daily sentiment')

ax1.set_xticklabels(aapl.index, rotation='vertical')
plt.show()

# %% [markdown]
# # CUMSUM WEEKENDS TO MONDAY [TO DO]

# %% [markdown]
# It would be nice to accumulate sentiment on weekends/holidays and add them to the next open trading session.

# %%
aapl['Close']

# %%
daily_sentiment.dates[::-1]

# %%
non_trading_days = list(set(daily_sentiment.dates[::-1]) - set(aapl.index))
non_trading_days.sort()
non_trading_days

# %%
daily_sentiment

# %%
aapl.index

# %%
(daily_sentiment.dates[0] - daily_sentiment.dates[1] == timedelta(days=1))

# %%
[1 if (daily_sentiment.dates[i] - daily_sentiment.dates[i+1] == timedelta(days=1)) else 0 for i in range(daily_sentiment.shape[0]-1)]

# %%
is_consec = [True if (non_trading_days[i+1] - non_trading_days[i] == timedelta(days=1)) else False for i in range(len(non_trading_days)-1)]
is_consec

# %%
daily_sentiment.dates

# %% [markdown]
# # MORE DATA

# %% [markdown]
# The twitter API only allows to fetch 7 days of tweets for a given hashtag. So we could instead collect data from a user/handle (no date restrictions).

# %%
auth = tweepy.OAuthHandler(twitter_credentials.CONSUMER_KEY, twitter_credentials.CONSUMER_SECRET)
api = tweepy.API(auth)

tweet_collector = TweetCollector()

# %%
users = ['realDonaldTrump', 'federalreserve', 'CNBC', 'Benzinga', 'Stocktwits', 'BreakoutStocks', 'bespokeinvest',
        'WSJmarkets', 'nytimesbusiness', 'IBDinvestors', 'WSJDealJournal']

# %%
df = {}

for user in users:
    
    tweets = api.user_timeline(screen_name=user, count=100)
    tweets_df = tweet_collector.tweets_to_data_frame(tweets)
    tweets_df['tweets'] = pd.DataFrame([tweet_collector.clean_tweet(tweet) for tweet in tweets_df['tweets']])
    tweets_df = tweets_df.drop_duplicates(subset=['tweets'])
    #tweets_df['sentiment'] = np.array([tweet_collector.analyze_sentiment(tweet) for tweet in tweets_df['tweets']])

    df[user] = tweets_df

# %% [markdown]
# # Sentiment Prediction

# %%
import transformers
import torch
from torch import nn
from transformers import BertModel

# %%
class SentimentClassifier(nn.Module):
    
    def __init__(self, n_classes):
        super(SentimentClassifier, self).__init__()
        self.bert = BertModel.from_pretrained(PRE_TRAINED_MODEL_NAME)
        self.drop = nn.Dropout(p=0.3)
        self.out = nn.Linear(self.bert.config.hidden_size, n_classes)
        
    def forward(self, input_ids, attention_mask):
        _, pooled_output = self.bert(
            input_ids=input_ids,
            attention_mask=attention_mask
        )
        output = self.drop(pooled_output)
        return self.out(output)

# %%
#df = pd.read_csv("tweets_df.csv")

# %%
MAX_LEN=160
PRE_TRAINED_MODEL_NAME = 'bert-base-uncased'
class_names = ['negative', 'neutral', 'positive']
device='cuda'

# %%
model = SentimentClassifier(len(class_names))
model.load_state_dict(torch.load('model_1_2-Copy1.pth'))
model = model.to(device)

# %%
tokenizer = transformers.BertTokenizer.from_pretrained(PRE_TRAINED_MODEL_NAME)

# %%
for user in users:

    print('##################')
    print(f'USER: {user}')
    print('##################')
    for text in df[user].tweets[:10]:

        encoded_review = tokenizer.encode_plus(
            text,
            max_length=MAX_LEN,
            add_special_tokens=True,
            return_token_type_ids=False,
            pad_to_max_length=True,
            return_attention_mask=True,
            return_tensors='pt'
        )

        input_ids = encoded_review['input_ids'].to(device)
        attention_mask = encoded_review['attention_mask'].to(device)

        output = model(input_ids, attention_mask)
        _, prediction = torch.max(output, dim=1)

        print(f'Review text: {text}')
        print(f'Sentiment : {class_names[prediction]}')
        print('-'*10)
# Out:
# ##################
# USER: realDonaldTrump
# ##################
# Review text: Thank you to Senator Bill Cassidy of Louisiana for his very smart words on the just signed Executive Orders
# Sentiment : positive
# ----------
# Review text: Portland which is out of control should finally after almost 3 months bring in the National Guard The Mayor an
# Sentiment : negative
# ----------
# Review text: RINO Ben Sasse who needed my support and endorsement in order to get the Republican nomination for Senate from the
# Sentiment : negative
# ----------
# Review text: So now Schumer and Pelosi want to meet to make a deal Amazing how it all works isn t it Where have they been for
# Sentiment : neutral
# ----------
# Review text: who just made a fool of himself as he got taken apart by only lasted 11 days in his fa
# Sentiment : negative
# ----------
# Review text: This is Fake News by the failing amp bad ratings Never suggested it although based on all of the many
# Sentiment : negative
# ----------
# Review text:
# Sentiment : positive
# ----------
# Review text: RT See you in less than 1 hour on Fox 8 PM eastern when I sit down with AG Barr for the entire show Please don t miss
# Sentiment : negative
# ----------
# Review text: RT TONIGHT AT 8 PM EASTERN AG BILL BARR IS MY GUEST FOR THE FULL HOUR ON LIFE LIBRTY amp LEVIN ON FOX IF YOU CAN T WATCH
# Sentiment : positive
# ----------
# Review text: RT This amazing American is on FIRE Leo on Bidens racist comments Blacks are INDIVIDUALS We don t vote
# Sentiment : negative
# ----------
# ##################
# USER: federalreserve
# ##################
# Review text: releases third issue of article series on financial conditions and concerns of consumers and commun
# Sentiment : negative
# ----------
# Review text: announces individual large bank capital requirements which will be effective on October 1
# Sentiment : negative
# ----------
# Review text: Now available Weekly data on the Assets and Liabilities of Commercial Banks in the United States FedData
# Sentiment : negative
# ----------
# Review text: Q2 consumer credit down 6 7 revolving credit down 31 8 nonrevolving credit up 1 9 June consumer credit up 2 6
# Sentiment : neutral
# ----------
# Review text: Follow us on social media careers
# Sentiment : negative
# ----------
# Review text: Register today for webinar Tips on Winning Contracts The Federal Reserve Board s Acquisition Road Map August 12
# Sentiment : negative
# ----------
# Review text: See next week s calendar of events
# Sentiment : neutral
# ----------
# Review text: Interactive guide to our weekly BalanceSheet report FedData
# Sentiment : positive
# ----------
# Review text: Our weekly BalanceSheet update FedData
# Sentiment : neutral
# ----------
# Review text: Governor Brainard delivers remarks about the future of retail payments in the United States at FedNow Service eve
# Sentiment : negative
# ----------
# ##################
# USER: CNBC
# ##################
# Review text: New for subscribers Outgoing New York Times CEO on the stock s 400 run and what happens there if Donald Trump lo
# Sentiment : negative
# ----------
# Review text: The new challenge for state election officials How much hand sanitizer is enough
# Sentiment : neutral
# ----------
# Review text: Airline shares surge as TSA numbers hit pandemic high support for second bailout builds
# Sentiment : negative
# ----------
# Review text: Nearly 80 of credit card holders say they re worried they won t be able to continue making even the minimum paymen
# Sentiment : negative
# ----------
# Review text: Have you considered adopting a dog or cat during the pandemic Here s what you need to know about the costs of owni
# Sentiment : neutral
# ----------
# Review text: RT Small business confidence rebounds from all time low but Main Street still has a long way to go Check out this piece from
# Sentiment : neutral
# ----------
# Review text: RT THIS THURSDAY We have another must watch CNBCatWork livestream will chat w the CIOs of amp ab
# Sentiment : positive
# ----------
# Review text: Coronavirus live updates Mnuchin says relief deal could come this week TSA screenings return to March levels
# Sentiment : neutral
# ----------
# Review text: Desperate parents are turning to learning pods this fall Here s what it can cost investinyou In partnership wi
# Sentiment : negative
# ----------
# Review text: McDonald s is trying to recover millions in compensation it paid out to former CEO Steve Easterbrook suing him for
# Sentiment : negative
# ----------
# ##################
# USER: Benzinga
# ##################
# Review text: Kodak KODK 765M Federal Loan For Generic Drugs Paused Until Allegations Are Probed
# Sentiment : negative
# ----------
# Review text: CGC Canopy Growth Implements Renewed Strategy As Revenue Climbs 22
# Sentiment : positive
# ----------
# Review text: Hyundai Shares Soar 15 In Seoul As It Announces Dedicated Electric Vehicle Brand
# Sentiment : negative
# ----------
# Review text: GNUS Genius Brands Reports Purchase Of 230 New Episodes Of Programming Including Yu Gi Oh ARC V No Terms Discl
# Sentiment : negative
# ----------
# Review text: 10 Biggest PriceTarget Changes For Monday
# Sentiment : negative
# ----------
# Review text: PreMarket Prep Kodak s loan is put on hold August 10 via
# Sentiment : negative
# ----------
# Review text: TSLA Tesla going shopping
# Sentiment : neutral
# ----------
# Review text: Canopy Growth Q1 EPS 0 30 Up From 0 54 YoY Net Revenue C 110M Up 22 YoY CGC
# Sentiment : neutral
# ----------
# Review text: Watchlist
# Sentiment : positive
# ----------
# Review text: What Is On The Move 38 Stocks
# Sentiment : negative
# ----------
# ##################
# USER: Stocktwits
# ##################
# Review text: RT KODK Halted due to volatility
# Sentiment : negative
# ----------
# Review text: MGM stock surges after IAC takes 12 stake in a bet on online gaming MGM 22 pre market
# Sentiment : negative
# ----------
# Review text: Nikola Wins Order for 2 500 Electric Garbage Trucks NKLA 10 pre market
# Sentiment : negative
# ----------
# Review text: RT Kodak is now 85 off the highs and 600 off the lows
# Sentiment : neutral
# ----------
# Review text: Marijuana Stocks Canopy Earnings Report Better Than Expected Tilray Faces Make Or Break Quarter CGC 9 pre
# Sentiment : neutral
# ----------
# Review text: Eastman Kodak s 765 million U S loan agreement on hold after recent allegations KODK 40 pre market
# Sentiment : negative
# ----------
# Review text: Futures this morning S amp P 500 0 08 Nasdaq 0 04 Russell 2k 0 40 Dow Jones 0 32
# Sentiment : negative
# ----------
# Review text: Subscribe to to get tomorrow s special newsletter on where athletes like and
# Sentiment : negative
# ----------
# Review text: The Weekend Rip 2nd Highest Weekly Close Ever
# Sentiment : positive
# ----------
# Review text: RT 3 Financial History Sunday Reads Electric Vehicles A 19th Century Innovation Tech Revolutions Bicycle Mania Sketchy
# Sentiment : neutral
# ----------
# ##################
# USER: BreakoutStocks
# ##################
# Review text: 5 Top Stocks Close to Breaking Out 6 05am pst
# Sentiment : negative
# ----------
# Review text: Stocks to Watch 5 11pm pst
# Sentiment : negative
# ----------
# Review text: Big Booming Breakouts
# Sentiment : negative
# ----------
# Review text: Biggest Breakouts within the last Month KODK MARA MIST
# Sentiment : positive
# ----------
# Review text: Sometimes the best thing to do in the market is nothing stocks
# Sentiment : neutral
# ----------
# Review text: High Frequency Breakdowns
# Sentiment : negative
# ----------
# Review text: Top Performing Breakout Stocks of the Week CNDT ATHE GRPN
# Sentiment : positive
# ----------
# Review text: High relative volume breakout stocks
# Sentiment : positive
# ----------
# Review text: Facebook FB breakout stats
# Sentiment : positive
# ----------
# Review text: GE GRPN CNDT UFS hit new breakout highs
# Sentiment : positive
# ----------
# ##################
# USER: bespokeinvest
# ##################
# Review text: 24 stocks with market caps over 1 billion are currently down over 20 from 52 week highs seen in the last month
# Sentiment : negative
# ----------
# Review text: Bespoke Morning Lineup 8 10 20 by
# Sentiment : neutral
# ----------
# Review text: Trump s odds to win have risen back up near 40 over the last week or so as states like North Carolina have tighten
# Sentiment : neutral
# ----------
# Review text: US equity index ETFs start the new trading week mostly in extreme overbought territory as shown in our Trend Analyz
# Sentiment : negative
# ----------
# Review text: RT Can t say too much more about it but this weekend s Bespoke Report from the gents at was a ripping read W
# Sentiment : negative
# ----------
# Review text: Remember when the trade war and Mideast tensions were the biggest problems facing the market How quaint
# Sentiment : positive
# ----------
# Review text: Thanks Brendan Glad you liked it
# Sentiment : positive
# ----------
# Review text: Sure is
# Sentiment : positive
# ----------
# Review text: Home made vaccines policy support biotech longshots and more in this week s Bespoke Brunch Reads
# Sentiment : positive
# ----------
# Review text: Congrats George and Raquel Too bad we had to say it over Twitter
# Sentiment : neutral
# ----------
# ##################
# USER: WSJmarkets
# ##################
# Review text: Further weakening in the lira could dampen Turkey s appetite for European imports and strain businesses ability to
# Sentiment : neutral
# ----------
# Review text: So far this year U S listed biotechs have raised roughly 9 4 billion in IPOs already beating the 6 5 billion r
# Sentiment : positive
# ----------
# Review text: The Dow and S amp P 500 opened the week higher as investors assessed the pace of coronavirus infections fresh federal
# Sentiment : neutral
# ----------
# Review text: The stock market s selloff and rebound occurred very rapidly in the first half That was a challenge for long short
# Sentiment : negative
# ----------
# Review text: RT Think you can do better than me and our other esteemed columnists Make your pick here
# Sentiment : neutral
# ----------
# Review text: RT Twitter investors hit like button on weekend report from wells amp of preliminary TikTok talks St
# Sentiment : negative
# ----------
# Review text: RT Economic ties once smoothed strains between the U S and China but businesses now have less power to de escalate tensions
# Sentiment : neutral
# ----------
# Review text: Twitter has had preliminary talks with TikTok about a potential combination with its U S operations people famili
# Sentiment : neutral
# ----------
# Review text: Steve Jobs s creation has turned into Tim Cook s Apple a triumph of method over magic
# Sentiment : positive
# ----------
# Review text: It s 2008 all over again Covid s financial fallout is a second blow to millennials who are still struggling fro
# Sentiment : negative
# ----------
# ##################
# USER: nytimesbusiness
# ##################
# Review text: Inovio has boasted about its coronavirus vaccine But the company faces challenges on nearly every front
# Sentiment : negative
# ----------
# Review text: The Saudi government owns most of Saudi Aramco and that influence is reflected in its earnings report
# Sentiment : positive
# ----------
# Review text: Amid controversies and an advertiser boycott Fox News drew more viewers in June and July from 8 to 11 p m than ev
# Sentiment : negative
# ----------
# Review text: Congress can t agree on an aid package and President Trump s executive orders may not resolve things America s jo
# Sentiment : negative
# ----------
# Review text: Things generally are substantially better than our worst fears 90 days ago said an investor at a Silicon Valley
# Sentiment : neutral
# ----------
# Review text: Amazon got F C C approval to get into the high speed internet satellite business with Project Kuiper Astronomers
# Sentiment : neutral
# ----------
# Review text: In the Trump era a specific kind of misinformation on social media is a central tactic of the right writes
# Sentiment : negative
# ----------
# Review text: Joe Biden has criticized the big tech companies But his campaign and transition teams have welcomed allies of Face
# Sentiment : neutral
# ----------
# Review text: If all of President Trump s directives on emergency pandemic aid take effect here s how experts believe they could
# Sentiment : negative
# ----------
# Review text: After a whirlwind of mixed test results Gov Mike DeWine of Ohio maintained that people shouldn t take his experie
# Sentiment : negative
# ----------
# ##################
# USER: IBDinvestors
# ##################
# Review text: MarketSmithSharkWeek is here Take a bite out of this offer to boost your profits Don t hesitate Get started whe
# Sentiment : negative
# ----------
# Review text: RT Want to get an edge in the market Watch this video to learn what this week s sector rotation means for next week s tradi
# Sentiment : neutral
# ----------
# Review text: RT ECarson Stock market leadership expands despite some high profile crashes but here are four risks to watch
# Sentiment : neutral
# ----------
# Review text: It s MarketSmith Shark Week Win this 2020 s been a volatile year so far Tag a friend and tell us which stock has
# Sentiment : negative
# ----------
# Review text: Want to get an edge in the market Watch this video to learn what this week s sector rotation means for next week s
# Sentiment : neutral
# ----------
# Review text: High Flyers Continue Sell Off How To Protect Your Portfolio GSX NVDA TMUS
# Sentiment : negative
# ----------
# Review text: Big Week For Chinese Stocks Coming Up Investing Action Plan
# Sentiment : positive
# ----------
# Review text: It s the start of MarketSmithSharkWeek Sink your teeth into bigger profits and get this special offer now Click
# Sentiment : negative
# ----------
# Review text: RT ECarson The sun is shining on Wall Street but continued cloud software woes among two key risks for the stock market rally now
# Sentiment : neutral
# ----------
# Review text: Founder of The Stock Market Mentor joined Irusha on this week s podcast to discuss work fro
# Sentiment : positive
# ----------
# ##################
# USER: WSJDealJournal
# ##################
# Review text: Follow our new blog for the latest news and analysis on global finance M amp A and markets
# Sentiment : positive
# ----------
